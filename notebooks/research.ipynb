# %%
import sys
print(sys.executable)
# Out:
# d:\Flight_Fare_Prediction\env\python.exe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel(r"D:\Flight_Fare_Prediction\notebooks\data\Data_Train.xlsx")

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
data.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10678              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %%
# getting 5 random sample
data.sample(5)
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 1596           SpiceJet      12/06/2019   Kolkata    Banglore
# 5720             IndiGo       3/03/2019     Delhi      Cochin
# 5220           SpiceJet       3/05/2019  Banglore       Delhi
# 3487          Air India      27/05/2019     Delhi      Cochin
# 1812  Multiple carriers      15/05/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 1596        CCU → PNQ → BLR    08:35         17:15   8h 40m      1 stop
# 5720        DEL → BOM → COK    08:25         21:00  12h 35m      1 stop
# 5220              BLR → DEL    05:55         08:35   2h 40m    non-stop
# 3487  DEL → LKO → BOM → COK    12:20  19:15 28 May  30h 55m     2 stops
# 1812        DEL → BOM → COK    10:35         19:15   8h 40m      1 stop
#
#      Additional_Info  Price
# 1596         No info   7189
# 5720         No info  14871
# 5220         No info   3625
# 3487         No info  12488
# 1812         No info   7575

# %%
# Checking for missing values
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
### dropping null values as there are 1-2 only
data.dropna(inplace = True)

# %%
data.shape
# Out:
# (10682, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10682 non-null  object
#  1   Date_of_Journey  10682 non-null  object
#  2   Source           10682 non-null  object
#  3   Destination      10682 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10682 non-null  object
#  6   Arrival_Time     10682 non-null  object
#  7   Duration         10682 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10682 non-null  object
#  10  Price            10682 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 1001.4+ KB

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# # Column : Date_of_Journey
#
# - From data.info() we get to know that Date_of_Journey is of object data type, so we are converting it into timestamp.
# - Using pandas function : to_datetime
# - Not considering year , because the whole data is of same year

# %%
## Extracting only day of the date 
data['Day'] = pd.to_datetime(data['Date_of_Journey'], format = "%d/%m/%Y").dt.day

# %%
## Extracting only month of the date 
data['Month'] = pd.to_datetime(data['Date_of_Journey'], format = "%d/%m/%Y").dt.month

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  Month  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897      3
# 1    05:50         13:15   7h 25m     2 stops         No info   7662      5
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882      6
# 3    18:05         23:30   5h 25m      1 stop         No info   6218      5
# 4    16:50         21:35   4h 45m      1 stop         No info  13302      3
#
#    Day
# 0   24
# 1    1
# 2    9
# 3   12
# 4    1

# %%
# dropping Date_of_Journey column as we took out the important aspects within it
# axis = 1 as we are dropping column 
data.drop(['Date_of_Journey'], axis = 1, inplace = True)

# %% [markdown]
# # Column : Dep_Time
#
# - From Departure Time, we want to extract Hour and Minutes
# - Using pandas function : to_datetime
# - Then dropping Dep_Time column

# %%
## Extracting Hours 
data['Dep_Hour'] = pd.to_datetime(data['Dep_Time'], format ="%H:%M").dt.hour

## Extracting Minutes 
data['Dep_Min'] = pd.to_datetime(data['Dep_Time'], format= "%H:%M" ).dt.minute

# %%
## Dropping Dep_Time Column
data.drop(['Dep_Time'], axis = 1 , inplace = True)

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price  Month  Day  Dep_Hour  Dep_Min
# 0   2h 50m    non-stop         No info   3897      3   24        22       20
# 1   7h 25m     2 stops         No info   7662      5    1         5       50
# 2      19h     2 stops         No info  13882      6    9         9       25
# 3   5h 25m      1 stop         No info   6218      5   12        18        5
# 4   4h 45m      1 stop         No info  13302      3    1        16       50

# %% [markdown]
# # Column : Arrival_Time
#
# - From arrival Time, we want to extract Hour and Minutes, similar to Dep_Time
# - The format of 'Arrival_Time' column, have a mix of entries with and without dates.
# - So, creating a function that extracts hour & minutes from Arrival_Time, and then applying function to Arrival_Time to create a new columns with extracted hours & minutes.
# - Then dropping Arrival_Time column

# %%
## Extracting Hours
data['Arr_Hour'] = data['Arrival_Time'].apply(lambda x: pd.to_datetime(x, errors='coerce').hour)

## Extracting Minutes
data['Arr_Minute'] = data['Arrival_Time'].apply(lambda x: pd.to_datetime(x, errors='coerce').minute)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Flight_Fare_Prediction\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Arrival_Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15172/3822516369.py in <module>
#       1 ## Extracting Hours
# ----> 2 data['Arr_Hour'] = data['Arrival_Time'].apply(lambda x: pd.to_datetime(x, errors='coerce').hour)
#       3
#       4 ## Extracting Minutes
#       5 data['Arr_Minute'] = data['Arrival_Time'].apply(lambda x: pd.to_datetime(x, errors='coerce').minute)
#
# d:\Flight_Fare_Prediction\env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# d:\Flight_Fare_Prediction\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Arrival_Time'

# %%
## Dropping Arrival_Time Column
data.drop(['Arrival_Time'], axis = 1 , inplace = True)

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info  Price  Month  Day  Dep_Hour  Dep_Min  Arr_Hour  \
# 0    non-stop         No info   3897      3   24        22       20         1
# 1     2 stops         No info   7662      5    1         5       50        13
# 2     2 stops         No info  13882      6    9         9       25         4
# 3      1 stop         No info   6218      5   12        18        5        23
# 4      1 stop         No info  13302      3    1        16       50        21
#
#    Arr_Minute
# 0          10
# 1          15
# 2          25
# 3          30
# 4          35

# %%
def extract_duration(duration):
    hours = 0
    minutes = 0

    # Split the string based on space and remove any empty parts
    parts = [part.strip() for part in duration.split()]

    for part in parts:
        if 'h' in part:
            hours += int(part.replace('h', ''))
        elif 'm' in part:
            minutes += int(part.replace('m', ''))
        else:
            # If no 'h' or 'm' is present, consider it as hours
            hours += int(part)

    return hours, minutes

# Creating new columns for hours and minutes
data['Duration_Hour'], data['Duration_Min'] = zip(*data['Duration'].apply(extract_duration))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Flight_Fare_Prediction\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15172/2168379753.py in <module>
#      18
#      19 # Creating new columns for hours and minutes
# ---> 20 data['Duration_Hour'], data['Duration_Min'] = zip(*data['Duration'].apply(extract_duration))
#      21
#
# d:\Flight_Fare_Prediction\env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# d:\Flight_Fare_Prediction\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Duration'

# %%
## Dropping Duration Column
data.drop(['Duration'], axis = 1 , inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15172/2303741792.py in <module>
#       1 ## Dropping Duration Column
# ----> 2 data.drop(['Duration'], axis = 1 , inplace = True)
#
# d:\Flight_Fare_Prediction\env\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# d:\Flight_Fare_Prediction\env\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# -> 4711                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4712
#    4713         if inplace:
#
# d:\Flight_Fare_Prediction\env\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4751                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4752             else:
# -> 4753                 new_axis = axis.drop(labels, errors=errors)
#    4754             indexer = axis.get_indexer(new_axis)
#    4755
#
# d:\Flight_Fare_Prediction\env\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6998         if mask.any():
#    6999             if errors != "ignore":
# -> 7000                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001             indexer = indexer[~mask]
#    7002         return self.delete(indexer)
#
# KeyError: "['Duration'] not found in axis"

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info  Price  Month  Day  Dep_Hour  Dep_Min  Arr_Hour  Arr_Minute  \
# 0         No info   3897      3   24        22       20         1          10
# 1         No info   7662      5    1         5       50        13          15
# 2         No info  13882      6    9         9       25         4          25
# 3         No info   6218      5   12        18        5        23          30
# 4         No info  13302      3    1        16       50        21          35
#
#    Duration_Hour  Duration_Min
# 0              2            50
# 1              7            25
# 2             19             0
# 3              5            25
# 4              4            45

# %% [markdown]
# ### Handling Categorical Data

# %% [markdown]
# ## Column : Airline

# %%
data['Airline'].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64
